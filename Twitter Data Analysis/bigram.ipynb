# %%
import pandas as pd
import pandas as pd   
import numpy as np  
import json  
import os  
from pandas.io.json import json_normalize
from nltk.corpus import stopwords  
import sys  
import re
import numpy as np
import collections,re
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import matplotlib.pyplot as plt
# %matplotlib inline
import nltk
from wordcloud import WordCloud
import pandas as pd
import numpy as np

# %%
#Preprocessing

data=pd.DataFrame.from_csv('Donald.csv')
data_ar =np.array(data)
text= data_ar[:,0]

# %%
type(text)
# Out:
# numpy.ndarray

# %%
#Export to file



pds=pd.DataFrame(text)

pds.to_csv('foo1.csv', sep=',')

# %%
#Create Trump cloud


from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

d = path.dirname('__file__')

# Read the whole text.

text = open(path.join(d, 'foo1.csv')).read()

text= merged_text

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = imread(path.join(d, "Tmp.png"))

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=STOPWORDS.add("said"))
# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "trumpwordcl.png"))

# show
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()

# %%
# Hillary Preprocessing

data=pd.DataFrame.from_csv('temp_hillary.csv')
data_ar =np.array(data)
text= data_ar[:,0]

# %%
type(text)
# Out:
# numpy.ndarray

# %%
#Export to file



pds = pd.DataFrame(text)
pds.to_csv('foo.csv', sep=',')

# %%
#Create Trump cloud


from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

d = path.dirname('__file__')

# Read the whole text.

text = open(path.join(d, 'foo.csv')).read()

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = imread(path.join(d, "Hil.jpg"))

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=STOPWORDS.add("said"))
# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "Hilwordcl.png"))

# show
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()

# %%
# Task 2 - Remove stopwords and preprocess tweets




#Preprocessing

data=pd.DataFrame.from_csv('Donald.csv')
data_ar =np.array(data)
text= data_ar[:,0]

# %%
text = ' '.join([i for i in data.Text.tolist()])


#Draw wordcloud

def draw_wordcloud(s):
    wordcloud = WordCloud(max_font_size=40, max_words = 200, background_color="white").generate(s)
    plt.figure(figsize = (10,7))
    plt.imshow(wordcloud)

# %%
#tokenize

tokens = nltk.tokenize.word_tokenize(text)

tokens2=list()

# %%
type(text)
# Out:
# str

# %%
# Out:
# numpy.ndarray

# %%
import numpy as np

text=np.asarray(text)

# %%
from nltk.corpus import stopwords


k= len(tokens)

for i in range(0, k):
    if tokens[i].isalpha():
        tokens2.append(tokens[i])

        
tokens=list()
tokens=tokens2


st = stopwords.words('english')

tokens2=list()

for i in range(0, len(tokens)-1):
    if tokens[i].lower() not in st:
        tokens2.append(tokens[i])
        
tokens=list()
tokens=tokens2

text = ' '.join([i for i in tokens])

import itertools
df2 = pd.read_csv('word.csv')

k= df2.values.tolist()

lst = list(itertools.chain(*k))

s= set()

for i in lst:
    s.add(i)

s1= set()
for i in tokens:
    s1.add(i)

common = s & s1

tokens=list(common)

merged_text = ' '.join([i for i in common])

# %%
#tokens.append('')

len(tokens)
# Out:
# 3105

# %%
#tokens.append('')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer




text = np.split(np.asarray(tokens), len(tokens)/3)
text = [' '.join([j for j in i.tolist()]) for i in text]




vectorizer = TfidfVectorizer(max_features=1000)
vectorizer.fit_transform(text)
tokens = vectorizer.get_feature_names()


merged_text = ' '.join([i for i in tokens])

# %%
draw_wordcloud(merged_text)

# %%
#calculate Ngrams

# %%
data=pd.DataFrame.from_csv('donald.csv')

data_ar =np.array(data)

# %%
#len(data_ar)

# %%
text= data_ar[:,0] 


for i in range(0,len(data_ar)):
    #URLless_string = re.sub(r'^https?:\/\/.*[\r\n]*', '', text[i], flags=re.MULTILINE)
    
    URLless_string = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^https\s/]*))*', '', text[i],flags=re.MULTILINE)
    data_ar[i,0]=  URLless_string
    
    
text= data_ar[:,0]

# %%
filtered_words = [word for word in text if word not in stopwords.words('english')]


for i in range(0,len(filtered_words)):
    data_ar[i,0] = filtered_words[i]


dframe= pd.DataFrame(data_ar)





dframe.to_csv('data_donald.csv',delimiter=',')

# %%
#store for ngram evaluation

text=data_ar[:,0]

# %%
#Count positive negative if needed

count_word = re.findall(r'\w+', open('neu.csv').read().lower())

count_word1 = re.findall(r'\w+', open('pos.csv').read().lower())
count_word0 = re.findall(r'\w+', open('neg.csv').read().lower())

# %%
#console
#Counter(count_word).most_common(10)


#NGRAM EVALUATION

def find_ngrams(input_list, n):
  return zip(*[input_list[i:] for i in range(n)])
  



#for i in range(0,len(d2)):
   # l12.append(tknzr.tokenize(d2[i]))




bigrams = [(ele, tex.split()[i+1]) for tex in text  for i,ele in enumerate(tex.split()) if i < len(tex.split())-1]

Trigrams = [(ele, tex.split()[i+1],tex.split()[i+2]) for tex in text  for i,ele in enumerate(tex.split()) if i < len(tex.split())-2]  


#console
#Counter(bigrams).most_common(10)


#console
#Counter(Trigrams).most_common(10)

# %%
from collections import Counter


Counter(Trigrams).most_common(100)
# Out:
# [(('your', 'tax', 'returns'), 297),
#  (('tax', 'returns', 'and'), 296),
#  (('returns', 'and', "I'll"), 296),
#  (('Release', 'your', 'tax'), 295),
#  (("I'll", 'stop.', 'Ha'), 294),
#  (('...@realDonaldTrump', 'Release', 'your'), 294),
#  (('and', "I'll", 'stop.'), 294),
#  (('RT', '@ABFalecbaldwin:', '...@realDonaldTrump'), 293),
#  (('@ABFalecbaldwin:', '...@realDonaldTrump', 'Release'), 293),
#  (('RT', '@cafedotcom:', '.@realDonaldTrump'), 70),
#  (('@cafedotcom:', '.@realDonaldTrump', 'Mr.'), 68),
#  (('.@realDonaldTrump', 'Mr.', 'Trump'), 68),
#  (('amazing', 'orator,', 'will'), 67),
#  (('will', 'have', 'historic'), 67),
#  (('Mr.', 'Trump', 'is'), 67),
#  (('orator,', 'will', 'have'), 67),
#  (('have', 'historic', 'quotes'), 67),
#  (('quotes', 'as', 'POTUS!'), 67),
#  (('is', 'an', 'amazing'), 67),
#  (('an', 'amazing', 'orator,'), 67),
#  (('historic', 'quotes', 'as'), 67),
#  (('Trump', 'is', 'an'), 67),
#  (('impersonation', 'of', 'a'), 44),
# ...

# %%
Counter(bigrams).most_common(100)
# Out:
# [(('and', "I'll"), 306),
#  (('your', 'tax'), 300),
#  (('tax', 'returns'), 299),
#  (('returns', 'and'), 296),
#  (('Release', 'your'), 295),
#  (('stop.', 'Ha'), 294),
#  (("I'll", 'stop.'), 294),
#  (('...@realDonaldTrump', 'Release'), 294),
#  (('@ABFalecbaldwin:', '...@realDonaldTrump'), 293),
#  (('RT', '@ABFalecbaldwin:'), 293),
#  (('@realDonaldTrump', 'I'), 117),
#  (('of', 'the'), 86),
#  (('to', 'be'), 81),
#  (('@realDonaldTrump', 'you'), 79),
#  (('is', 'an'), 78),
#  (('if', 'you'), 77),
#  (('Trump', 'is'), 76),
#  (('will', 'have'), 74),
#  (('@cafedotcom:', '.@realDonaldTrump'), 70),
#  (('RT', '@cafedotcom:'), 70),
#  (('.@realDonaldTrump', 'Mr.'), 68),
#  (('an', 'amazing'), 68),
#  (('@realDonaldTrump', 'You'), 68),
#  (('Mr.', 'Trump'), 68),
#  (('quotes', 'as'), 67),
#  (('have', 'historic'), 67),
#  (('amazing', 'orator,'), 67),
#  (('as', 'POTUS!'), 67),
#  (('orator,', 'will'), 67),
#  (('historic', 'quotes'), 67),
#  (('going', 'to'), 65),
# ...
